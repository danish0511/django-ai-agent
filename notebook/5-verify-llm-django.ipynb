# %%
import setup
setup.init()

# %%
from ai.llms import get_gemini_model

# %%
model = get_gemini_model()

# %%
model.invoke("Who are you?")
# Out:
# AIMessage(content='I am a large language model, trained by Google.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--ab0f57bf-38a2-4bf8-9cd2-e9f89b149532-0', usage_metadata={'input_tokens': 4, 'output_tokens': 12, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}})
