# %%
import setup
setup.init()

# %%
from ai.tools import list_documents, get_document

# %%
config = {
    "user_id":1
}

# %%
list_documents.invoke(None, config)
# Out:
# {'tags': [], 'metadata': {'user_id': 1}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 1}}
# [{'id': 1, 'title': 'Title'}]

# %%
get_document.invoke({"document_id":5}, config)
# Out:
# {'id': 5, 'title': 'Hello world'}

# %%
get_document.invoke({"document_id":7}, config)
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# File e:\clones\django-ai-agent\src\ai\tools.py:38, in get_document(document_id, config)
#      37 try:
# ---> 38     obj = Document.objects.get(id=document_id, active=True)
#      39 except Document.DoesNotExist:
#
# File e:\clones\django-ai-agent\venv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File e:\clones\django-ai-agent\venv\Lib\site-packages\django\db\models\query.py:633, in QuerySet.get(self, *args, **kwargs)
#     632 if not num:
# --> 633     raise self.model.DoesNotExist(
#     634         "%s matching query does not exist." % self.model._meta.object_name
# ...
